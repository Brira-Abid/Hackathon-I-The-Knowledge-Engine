# %%
# ============================
# CHAPTER 1: HOW ROBOTS SEE
# ============================
# This is an AI-NATIVE textbook chapter
# Readers can RUN and MODIFY this code!

print("🤖 WELCOME TO COMPUTER VISION! 🤖")
print("\nLesson 1: Computers see images as NUMBERS")

# Let's load an image
import cv2
import matplotlib.pyplot as plt
import numpy as np

print("\n📸 Loading a sample image...")

# Create a simple image programmatically (no downloads needed!)
# A 5x5 pixel "image" - tiny so we can see the numbers!
tiny_image = np.array([
    [0, 50, 100, 150, 200],      # Row 1: Dark to light pixels
    [255, 200, 150, 100, 50],    # Row 2: Light to dark
    [0, 0, 0, 0, 0],             # Row 3: All black
    [255, 255, 255, 255, 255],   # Row 4: All white
    [128, 128, 128, 128, 128]    # Row 5: All gray
])

print("\n🔢 Here's what the computer ACTUALLY sees:")
print("A 5x5 grid of numbers (0=black, 255=white):")
print(tiny_image)

print("\n👁️ And here's what HUMANS see:")
plt.imshow(tiny_image, cmap='gray', vmin=0, vmax=255)
plt.colorbar()
plt.title("Visualizing Pixel Values")
plt.show()

print("\n🎯 TRY CHANGING THE CODE ABOVE!")
print("Modify the numbers in 'tiny_image' array")
print("Then press RUN again to see changes!")
# Out:
# 🤖 WELCOME TO COMPUTER VISION! 🤖
#
# Lesson 1: Computers see images as NUMBERS
#
# 📸 Loading a sample image...
#
# 🔢 Here's what the computer ACTUALLY sees:
# A 5x5 grid of numbers (0=black, 255=white):
# [[   0   50 -100  150  200]
#  [ 255  200  150  100   50]
#  [   0    0    0    0    0]
#  [ 255  255  255  255  255]
#  [ 128  128  128  128  128]]
#
# 👁️ And here's what HUMANS see:
# 🎯 TRY CHANGING THE CODE ABOVE!
# Modify the numbers in 'tiny_image' array
# Then press RUN again to see changes!
